# %%
from runAll import run_all

run_all(verbose=True)
# Out:
#   S.CyberShake   | Constraint: Deadline | Nodes:  30 | Size:383.02
#   S.Montage      | Constraint:   Budget | Nodes:  25 | Size:632.69
#   S.Inspiral     | Constraint: Deadline | Nodes:  30 | Size:1490.36
#   S.CyberShake   | Constraint: Deadline | Nodes:  30 | Size:1529.85
#   S.CyberShake   | Constraint:   Budget | Nodes:  30 | Size:1790.43
#   S.Epigenomics  | Constraint:   Budget | Nodes:  24 | Size:2301.67
#   S.Inspiral     | Constraint: Deadline | Nodes:  30 | Size:2356.49
#   S.Epigenomics  | Constraint:   Budget | Nodes:  24 | Size:2370.79
#   S.Montage      | Constraint: Deadline | Nodes:  25 | Size:2553.93
#   S.Inspiral     | Constraint: Deadline | Nodes:  30 | Size:2590.78
# heft cost:180.0 | cost: 96.0 | heft ms:58.28 | ms:119.49 | Nodes:  30 | Deadline | factor:  8.06
# heft cost:288.0 | cost:288.0 | heft ms:110.97 | ms:110.97 | Nodes:  25 |   Budget | factor:  5.00
# heft cost:564.0 | cost:324.0 | heft ms:217.30 | ms:417.79 | Nodes:  30 | Deadline | factor:  9.22
# ...
